# %% [markdown]
# ![](../MISC/unnamed_1.png)

# %% [markdown]
# # Analysing Customer Churn Data - Predicting Behavior to Retain Customers

# %% [markdown]
# Rayyan Minhaj (Data Science Intern - 10Pearls)

# %% [markdown]
# ---

# %% [markdown]
# ## Module 1: Data Preprocessing, EDA, Feature Engineering
# The Telco Customer Churn Dataset is about customer churn for a telecommunications company, containing information on customer demographics, services, account information, and churn status.

# %%
import pandas as pd

df = pd.read_csv('TelcoCustomerChurn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# 21 Features (Columns) & 7032 Customers (Rows)

# %%
df.mean(numeric_only=True)
# Out:
# SeniorCitizen        0.162400
# tenure              32.421786
# MonthlyCharges      64.798208
# TotalCharges      2283.300441
# dtype: float64

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# We can analyse that there are no missing values in the features, however, there are are multiple values in some features that reference "No" with other textual context. In order to maintain the same naming convention we can simply replace those values in the dataframe.

# %%
df['MultipleLines'] = df['MultipleLines'].replace('No phone service', 'No')
df['OnlineSecurity'] = df['OnlineSecurity'].replace('No internet service', 'No')
df['OnlineBackup'] = df['OnlineBackup'].replace('No internet service', 'No')
df['DeviceProtection'] = df['DeviceProtection'].replace('No internet service', 'No')
df['TechSupport'] = df['TechSupport'].replace('No internet service', 'No')
df['StreamingTV'] = df['StreamingTV'].replace('No internet service', 'No')
df['StreamingMovies'] = df['StreamingMovies'].replace('No internet service', 'No')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# Before we decide which features might be useful for determining whether a customer is likely to stay or leave (churn) and one-hot encode them, we can visualise the dataset to better understand the current trends/stats.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors = ['#ff7f0e', '#1f77b4']

plt.figure(figsize=(4, 3))
sns.countplot(x='Churn', data=df, palette=colors)
plt.title('Distribution of Churn')
plt.show()


churn_counts = df['Churn'].value_counts()

plt.figure(figsize=(4, 4))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999'])
plt.title('Distribution of Churn ')
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5024\596758371.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette=colors)

# %% [markdown]
# We can clearly make out the imbalance between the majority of customers who did not churn and the ones who did.

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df[df['Churn'] == "No"]['tenure'], label='No Churn', kde=True, color='blue', bins=30)
sns.histplot(df[df['Churn'] == "Yes"]['tenure'], label='Churn', kde=True, color='red', bins=30)
plt.title('Distribution of Tenure for Churn and No Churn')
plt.xlabel('Tenure (Months)')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# Customers with lower tenure have a higher likelihood of churn.

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df[df['Churn'] == "No"]['MonthlyCharges'], label='No Churn', kde=True, color='blue', bins=30)
sns.histplot(df[df['Churn'] == "Yes"]['MonthlyCharges'], label='Churn', kde=True, color='red', bins=30)
plt.title('Distribution of Monthly Charges for Churn and No Churn')
plt.xlabel('Monthly Charges')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# Higher Monthly Charges seem to be associated with a higher likelihood of churn.

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['TotalCharges'], bins=30, kde=True) #30 intervals or data range. 
#30 bins typically offer enough detail to observe patterns and variations in the data without making the plot 
#too cluttered or difficult to interpret

plt.title('Distribution of Total Charges')
plt.show()

# %% [markdown]
# Total charges follow a right-skewed distribution, with most customers generating lower total charges.

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['MonthlyCharges'], bins=30, kde=True)
plt.title('Distribution of Monthly Charges')
plt.show()

# %%
df.to_csv("TelcoCustomerChurn2.csv", index=False)

# %% [markdown]
# Monthly charges are widely distributed, with a peak around the mid-range, indicating varied customer billing amounts.

# %% [markdown]
# ### Now we can One-Hot Encode the data

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].astype(object)

# %%
categorical_columns = df.select_dtypes(include=['object']).columns #We can only encode those columns that are categorical so its important to only select those columns

#Exclude 'customerID' column as it is a unique identifier
categorical_columns = categorical_columns[categorical_columns != 'customerID']

data_encoded = pd.get_dummies(df, columns=categorical_columns) #purposely not doing "drop_first=True" so that we can have a more comprehensive feature representation 
#but because we need only a single churn column as our target feature, i am dropping one of the two Churn columns

data_encoded = data_encoded.drop('Churn_No', axis=1)
data_encoded = data_encoded.rename(columns={'Churn_Yes': 'Churn'})


data_encoded.head()
# Out:
#    customerID  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0  7590-VHVEG       1           29.85         29.85           True
# 1  5575-GNVDE      34           56.95       1889.50          False
# 2  3668-QPYBK       2           53.85        108.15          False
# 3  7795-CFOCW      45           42.30       1840.75          False
# 4  9237-HQITU       2           70.70        151.65           True
#
#    gender_Male  SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  \
# 0        False             True            False       False         True
# 1         True             True            False        True        False
# 2         True             True            False        True        False
# 3         True             True            False        True        False
# 4        False             True            False        True        False
#
#    ...  Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 0  ...                     True              False              False
# 1  ...                    False               True              False
# 2  ...                     True              False              False
# 3  ...                    False               True              False
# 4  ...                     True              False              False
#
#    PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                False                  True
# 1                 True                 False
# 2                False                  True
# 3                 True                 False
# 4                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check  Churn
# 0                       False  False
# 1                        True  False
# 2                        True   True
# 3                       False  False
# 4                       False   True
#
# [5 rows x 41 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## HOLD ON!

# %% [markdown]
# ### Before we proceed, we can see that there is a significant imbalance in the Churn class!
# Which results in poor classification later on. In order to fix this we can try balancing the abundant/undersampled data uing Synthetic Minority Oversampling Technique (SMOTE) - also known as Synthetic Data!

# %% [markdown]
#  It works by selecting a data point from the minority class, finding its nearest neighbors, and generating new samples along the line segments between the point and its neighbors. This helps to increase the number of minority class instances without simply duplicating existing ones, leading to a more balanced and diverse dataset.

# %%
from imblearn.over_sampling import SMOTE

X = data_encoded.drop(['Churn', 'customerID'], axis=1)
y = data_encoded['Churn']

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

#Combine the resampled data into a new DataFrame
data_resampled = pd.concat([pd.DataFrame(X_res, columns=X.columns), pd.DataFrame(y_res, columns=['Churn'])], axis=1)

# %%
data_resampled.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0       1           29.85         29.85           True        False
# 1      34           56.95       1889.50          False         True
# 2       2           53.85        108.15          False         True
# 3      45           42.30       1840.75          False         True
# 4       2           70.70        151.65           True        False
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0             True            False       False         True           True
# 1             True            False        True        False           True
# 2             True            False        True        False           True
# 3             True            False        True        False           True
# 4             True            False        True        False           True
#
#    ...  Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 0  ...                     True              False              False
# 1  ...                    False               True              False
# 2  ...                     True              False              False
# 3  ...                    False               True              False
# 4  ...                     True              False              False
#
#    PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                False                  True
# 1                 True                 False
# 2                False                  True
# 3                 True                 False
# 4                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check  Churn
# 0                       False  False
# 1                        True  False
# 2                        True   True
# 3                       False  False
# 4                       False   True
#
# [5 rows x 40 columns]

# %%
churn_counts = data_resampled['Churn'].value_counts()

plt.figure(figsize=(4, 4))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999'])
plt.title('Customer Churn Distribution')
plt.show()

# %% [markdown]
# ---

# %%
data_resampled.to_csv('processed_churn_data.csv', index=False)

# %% [markdown]
# ### Plotting a Correlation Matrix now that we have encoded the features

# %% [markdown]
# To create a correlation matrix, the data must be in a numerical format. Encoding categorical variables is required because the correlation matrix requires numerical inputs to calculate the pairwise correlations between features

# %%
df_without_id= data_resampled #cant have anything besides numeric values
correlation_matrix = df_without_id.corr()


plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Customer Churn Data')
plt.show()

# %% [markdown]
# This matrix now represents the correlations between the numeric features and the one-hot encoded categorical features in the dataset. For example we can look at the hot/cold contrast between gender_Male and gender_Female.

# %% [markdown]
# Through this correlation map, we can deduce that:
# * Churn has a relatively strong positive correlation with MonthlyCharges and Contract_Month-to-month, indicating customers with higher monthly charges and month-to-month contracts are more likely to churn.
#
# * Churn has a negative correlation with tenure, Contract_One year, and Contract_Two year, suggesting customers with longer tenure and longer contracts are less likely to churn.
